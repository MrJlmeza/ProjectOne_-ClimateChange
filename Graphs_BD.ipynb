# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import scipy.stats as st
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import datetime

# %%
# File to Load (Remember to Change These)
surTc = "Resources/Population_SurfaceTemps_CO2_By_Country.csv"

# Read Purchasing File and store into Pandas data frame
final_df = pd.read_csv(surTc)

# %%
x_axis = final_df.loc[final_df["Country"]=="Brazil"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="Brazil"]["Land Temperature"]


correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Land Temperatures (C) by Decade - Brazil")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.94.

# %%
x_axis = final_df.loc[final_df["Country"]=="Brazil"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="Brazil"]["Population"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Population by Decade - Brazil")
plt.xlabel("Decades")
plt.ylabel("Population")
plt.show()
# Out:
# The correlation coefficient: 0.96.

# %%
x_axis = final_df.loc[final_df["Country"]=="Denmark"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="Denmark"]["Land Temperature"]
correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")


#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Land Temperatures (C) by Decade - Denmark")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.4.

# %%
x_axis = final_df.loc[final_df["Country"]=="Denmark"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="Denmark"]["Population"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Population by Decade - Denmark")
plt.xlabel("Decades")
plt.ylabel("Population")
plt.show()
# Out:
# The correlation coefficient: 0.99.
