# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import scipy.stats as st
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import datetime

# %%
file_path = "../Output/Population_SurfaceTemps_CO2_By_Country.csv"
final_df = pd.read_csv(file_path)
final_df.head()
# Out:
#    Decade        Country  Land Temperature   Population  Annual CO2 Emissions
# 0    1900  United States          8.448225   76391000.0          9.390961e+08
# 1    1910  United States          8.460250   92767000.0          1.447061e+09
# 2    1920  United States          8.755250  106881000.0          1.754044e+09
# 3    1930  United States          9.086992  123668000.0          1.543642e+09
# 4    1940  United States          8.924092  132637000.0          2.264069e+09

# %%
x_axis = final_df.loc[final_df["Country"]=="China"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="China"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Land Temperatures (C) by Decade - China")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.9.

# %%
x_axis = final_df.loc[final_df["Country"]=="India"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="India"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Land Temperatures (C) by Decade - India")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.93.

# %%
x_axis = final_df.loc[final_df["Country"]=="United States"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="United States"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Land Temperatures (C) by Decade - U.S.")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.79.

# %%
x_axis = final_df.loc[final_df["Country"]=="United Kingdom"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="United Kingdom"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 10), color="red")

plt.title("Land Temperatures (C) by Decade - U.K.")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.79.

# %%
x_axis = final_df.loc[final_df["Country"]=="China"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="China"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 5000000000), color="red")

plt.ylim(-1000000000, 8000000000)

plt.title("Annual CO2 Emissions by Decade - China")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.83.

# %%
x_axis = final_df.loc[final_df["Country"]=="India"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="India"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 1000000000), color="red")
plt.ylim(-1000000000, 8000000000)
plt.title("Annual CO2 Emissions by Decade - India")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.82.

# %%
x_axis = final_df.loc[final_df["Country"]=="United States"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="United States"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 5500000000), color="red")
plt.ylim(-1000000000, 8000000000)
plt.title("Annual CO2 Emissions by Decade - U.S.")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.98.

# %%
x_axis = final_df.loc[final_df["Country"]=="United Kingdom"]["Decade"]
y_axis = final_df.loc[final_df["Country"]=="United Kingdom"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 5500000000), color="red")
plt.ylim(-1000000000, 8000000000)
plt.title("Annual CO2 Emissions by Decade - U.K.")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.79.

# %%
labels = final_df["Decade"].unique().tolist()

y1 = np.array(final_df.loc[final_df["Country"]=="United Kingdom"]["Land Temperature"].unique())
y2 = np.array(final_df.loc[final_df["Country"]=="United States"]["Land Temperature"].unique())
y3 = np.array(final_df.loc[final_df["Country"]=="China"]["Land Temperature"].unique())
y4 = np.array(final_df.loc[final_df["Country"]=="India"]["Land Temperature"].unique())

print(len(y1))
print(len(y2))
print(len(y3))
print(len(y4))
y4
# men_means = [20, 34, 30, 35, 27]
# women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

# fig, ax = plt.subplots()
# rects1 = ax.bar(x - width/4, y1, width, label='United Kingdom')
# rects2 = ax.bar(x - width/2, y2, width, label='United States')
# rects3 = ax.bar(x + width/2, y3, width, label='China')
# rects4 = ax.bar(x + width/4, y4, width, label='India')

# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Land Temperatures (C)')
# ax.set_title('Land Temperatures by Country')
# ax.set_xticks(x)
# ax.set_xticklabels(labels)
# ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)
# ax.bar_label(rects3, padding=3)
# ax.bar_label(rects4, padding=3)

# fig.tight_layout()
# plt.ylim(5, 40)
# plt.show()


plt.bar(x, np.add(np.add(y4, y3, y2), y1), color='yellow', edgecolor='yellow')
plt.bar(x, np.add(np.add(y4, y3), y2), color='purple', edgecolor='purple')
plt.bar(x, np.add(y4, y3), color='green', edgecolor='green')
plt.bar(x, y4, color='orange', edgecolor='orange')
plt.xticks(x, labels)
plt.ylim(20, 100)
plt.show()
# Out:
# 11
# 11
# 11
# 11

# %%
labels = final_df["Decade"].unique().tolist()

labels

x = np.arange(len(labels))
uk = final_df.loc[final_df["Country"]=="United Kingdom"]["Land Temperature"].unique().tolist()
us = final_df.loc[final_df["Country"]=="United States"]["Land Temperature"].unique().tolist()
china = final_df.loc[final_df["Country"]=="China"]["Land Temperature"].unique().tolist()
india = final_df.loc[final_df["Country"]=="India"]["Land Temperature"].unique().tolist()

ax = plt.subplot()
# plt.figure(figsize=(200,3))
ax.bar(x-4, uk, width=.5, color='b', align='center')
ax.bar(x-2, us, width=.5, color='g', align='center')
ax.bar(x+2, china, width=.5, color='r', align='center')
ax.bar(x+4, india, width=.5, color='r', align='center')
ax.xaxis_date()
plt.tight_layout()

plt.show()

# %%
labels = final_df["Decade"].unique().tolist()
uk = final_df.loc[final_df["Country"]=="United Kingdom"]["Land Temperature"].unique().tolist()
us = final_df.loc[final_df["Country"]=="United States"]["Land Temperature"].unique().tolist()
china = final_df.loc[final_df["Country"]=="China"]["Land Temperature"].unique().tolist()
india = final_df.loc[final_df["Country"]=="India"]["Land Temperature"].unique().tolist()

men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, uk, width, label='United Kingdom')
rects2 = ax.bar(x + width/2, us, width, label='United States')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(3)
plt.show()

# %%
labels = final_df["Decade"].unique().tolist()
china = final_df.loc[final_df["Country"]=="China"]["Land Temperature"].unique().tolist()
india = final_df.loc[final_df["Country"]=="India"]["Land Temperature"].unique().tolist()

men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, india, width, label='India')
rects2 = ax.bar(x + width/2, china, width, label='China')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(3)
plt.show()
