# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import scipy.stats as st
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import datetime

# %%
cent_1900_file_path = "../Output/1900_Population_SurfaceTemps_CO2_By_Country.csv"
cent_1900_final_df = pd.read_csv(cent_1900_file_path)
cent_1900_final_df.head()

cent_1800_file_path = "../Output/1800_Population_SurfaceTemps_CO2_By_Country.csv"
cent_1800_final_df = pd.read_csv(cent_1800_file_path)
cent_1800_final_df.head()
# Out:
#    Decade        Country  Land Temperature  Population  Annual CO2 Emissions  \
# 0  1850.0  United States          8.334275  23579717.9            34075932.8
# 1  1860.0  United States          8.413042  31838900.7            62100036.8
# 2  1870.0  United States          8.471375  40240629.5           133686536.0
# 3  1880.0  United States          8.247875  50458000.0           274216324.8
# 4  1890.0  United States          8.309050  63302000.0           479073129.6
#
#    latitude  longitude
# 0  37.09024 -95.712891
# 1  37.09024 -95.712891
# 2  37.09024 -95.712891
# 3  37.09024 -95.712891
# 4  37.09024 -95.712891

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Brazil"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Brazil"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)

print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 25.5), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 25.4), color="red")
# plt.ylim(6, 8)
plt.title("Land Temperatures (C) in the 1900s - Brazil")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.94.

# %%
x_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="Brazil"]["Decade"]
y_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="Brazil"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)

print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1850, 24.45), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1850, 24.43), color="red")
# plt.ylim(6, 8)
plt.title("Land Temperatures (C) in the 1800s - Brazil")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.09.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Denmark"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Denmark"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)

print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, -16.6), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, -16.7), color="red")
# plt.ylim(6, 8)
plt.title("Land Temperatures (C) in the 1900s - Denmark")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.4.

# %%
x_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="Denmark"]["Decade"]
y_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="Denmark"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)

print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1850, -18.2), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1850, -18.37), color="red")
# plt.ylim(6, 8)
plt.title("Land Temperatures (C) in the 1800s - Denmark")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: -0.55.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="China"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="China"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)

print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 7.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 7.5), color="red")
plt.ylim(6, 8)
plt.title("Land Temperatures (C) in the 1900s - China")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.9.

# %%
x_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="China"]["Decade"]
y_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="China"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1850, 7.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1850, 7.5), color="red")
plt.ylim(6, 8)
plt.title("Land Temperatures (C) in the 1800s - China")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.54.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="India"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="India"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 24.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 24.5), color="red")
plt.ylim(23, 25)
plt.title("Land Temperatures (C) in the 1900s - India")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.93.

# %%
x_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="India"]["Decade"]
y_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="India"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1850, 24.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1850, 24.5), color="red")
plt.ylim(23, 25)
plt.title("Land Temperatures (C) in the 1800s - India")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.81.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 9.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 9.5), color="red")
plt.ylim(8, 10)
plt.title("Land Temperatures (C) in the 1900s - U.S.")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.79.

# %%
x_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="United States"]["Decade"]
y_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="United States"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1850, 9.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1850, 9.5), color="red")
plt.ylim(8, 10)
plt.title("Land Temperatures (C) in the 1800s - U.S.")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: -0.39.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United Kingdom"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United Kingdom"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 9.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 9.5), color="red")
plt.ylim(8, 10)
plt.title("Land Temperatures (C) in the 1900s - U.K.")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: 0.79.

# %%
x_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="United Kingdom"]["Decade"]
y_axis = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="United Kingdom"]["Land Temperature"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1850, 9.75), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1850, 9.5), color="red")
plt.ylim(8, 10)
plt.title("Land Temperatures (C) in the 1800s - U.K.")
plt.xlabel("Decades")
plt.ylabel("Land Temperatures (C)")
plt.show()
# Out:
# The correlation coefficient: -0.34.

# %% [markdown]
# CO2 Emissions

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Brazil"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Brazil"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 300000000), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 250000000), color="red")

# plt.ylim(-1000000000, 8000000000)

plt.title("Annual CO2 Emissions by Decade - Brazil")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.9.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Denmark"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="Denmark"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 60000000), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 50000000), color="red")

# plt.ylim(-1000000000, 8000000000)

plt.title("Annual CO2 Emissions by Decade - Denmark")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.94.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="China"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="China"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 7000000000), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 6000000000), color="red")

plt.ylim(-1000000000, 8000000000)

plt.title("Annual CO2 Emissions by Decade - China")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.83.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="India"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="India"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 7000000000), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 6000000000), color="red")

plt.ylim(-1000000000, 8000000000)
plt.title("Annual CO2 Emissions by Decade - India")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.82.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 7000000000), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 6000000000), color="red")
plt.ylim(-1000000000, 8000000000)
plt.title("Annual CO2 Emissions by Decade - U.S.")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.98.

# %%
x_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United Kingdom"]["Decade"]
y_axis = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United Kingdom"]["Annual CO2 Emissions"]

correlation_coeff = st.pearsonr(x_axis, y_axis)
print(f"The correlation coefficient: {round(correlation_coeff[0],2)}.")

#Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regression_value = slope * x_axis + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regression_value, "r-")
plt.annotate(line_equation, (1900, 610000000), color="red")
corr_coeff_str = "correlation coefficient:" + str(round(correlation_coeff[0],2))
plt.annotate(corr_coeff_str, (1900, 580000000), color="red")

# plt.ylim(-1000000000, 8000000000)
plt.title("Annual CO2 Emissions by Decade - U.K.")
plt.xlabel("Decades")
plt.ylabel("Annual CO2 Emissions (Metric Tons)")
plt.show()
# Out:
# The correlation coefficient: 0.79.

# %%
labels = cent_1900_final_df["Decade"].unique().tolist()
uk = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United Kingdom"]["Land Temperature"].unique().tolist()
us = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Land Temperature"].unique().tolist()
china = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="China"]["Land Temperature"].unique().tolist()
india = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="India"]["Land Temperature"].unique().tolist()

men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, uk, width, label='United Kingdom')
rects2 = ax.bar(x + width/2, us, width, label='United States')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(3)
plt.show()

# %%
labels = cent_1900_final_df["Decade"].unique().tolist()
china = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="China"]["Land Temperature"].unique().tolist()
india = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="India"]["Land Temperature"].unique().tolist()

men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, india, width, label='India')
rects2 = ax.bar(x + width/2, china, width, label='China')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(3)
plt.show()

# %% [markdown]
# Null Hypothesis

# %%
land_temp_USA_1900 = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Land Temperature"].mean()
co2_emissions_USA_1900 = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Annual CO2 Emissions"].mean()

# co2_emissions_USA_1900
land_temp_USA_1900 = cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Land Temperature"].mean()
land_temp_USA_1800 = cent_1800_final_df.loc[cent_1800_final_df["Country"]=="United States"]["Land Temperature"].mean()

print(f"USA mean temp, 1900: {land_temp_USA_1900}")
print(f"USA mean temp, 1800: {land_temp_USA_1800}")

st.ttest_1samp(land_temp_USA_1900.astype(float), land_temp_USA_1800.astype(float))
st.ttest_ind(land_temp_USA_1900.astype(float), land_temp_USA_1800.astype(float), equal_var=False)

st.ttest_1samp(cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Land Temperature"].mean(), cent_1900_final_df.loc[cent_1900_final_df["Country"]=="United States"]["Annual CO2 Emissions"].mean())


# st.ttest_1samp(5, 8)
# Out:
# USA mean temp, 1900: 8.915952272727274
# USA mean temp, 1800: 8.355123333333333
# Ttest_1sampResult(statistic=nan, pvalue=nan)
